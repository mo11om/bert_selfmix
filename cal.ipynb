# %%
import os 
os.path
# Out:
# <module 'posixpath' from '/home/mo1om/code/miniconda3/envs/t5/lib/python3.10/posixpath.py'>

# %%
import pandas as pd

# Replace 'input_file.csv' with the name of your original CSV file
file_path="data/split/test_split_5.csv"
df = pd.read_csv(file_path, usecols=['tag', 'text'])
df.head()
# Out:
#    tag                                               text
# 0  763  Accordingly, under the Separation Agreement, s...
# 1   64  Accordingly, under the Separation Agreement, s...
# 2  399  The Company estimates that an additional $<spa...
# 3  294  Due from related parties in the Condensed Cons...
# 4  294  Due from related parties in the Condensed Cons...

# %%
# Replace 'output_file.csv' with the desired name for the new CSV file
output_path="data/clean/test_split_5.csv"
df.to_csv(output_path, index=False)
